# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("/Users/HP/Downloads/Service Log (1).csv")
data.head()
# Out:
#    SeviceID  CustomerID              Date  Revenue  SAT_Score
# 0         0       11004  18-06-2003 00:00      240          6
# 1         1       11006  20-07-2004 00:00      280          7
# 2         2       11007  28-12-2003 00:00      210          7
# 3         3       11008  29-04-2005 00:00      290          5
# 4         4       11009  18-12-2003 00:00      350          9

# %%
data.describe().transpose()
# Out:
#               count        mean          std      min       25%      50%  \
# SeviceID    10000.0   4999.5000  2886.895680      0.0   2499.75   4999.5
# CustomerID  10000.0  20325.4693  5275.706913  11004.0  15824.75  20367.0
# Revenue     10000.0    295.5730   105.850329    190.0    220.00    280.0
# SAT_Score   10000.0      5.3066     2.111739      1.0      4.00      5.0
#
#                  75%      max
# SeviceID     7499.25   9999.0
# CustomerID  24853.25  29474.0
# Revenue       310.00   1180.0
# SAT_Score       7.00      9.0

# %%
data.isnull().sum()
# Out:
# SeviceID      0
# CustomerID    0
# Date          0
# Revenue       0
# SAT_Score     0
# dtype: int64

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data['Date'].describe()
# Out:
# <ipython-input-12-c2526e25cc24>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data['Date'].describe()
# count                   10000
# unique                   1255
# top       2003-01-08 00:00:00
# freq                       30
# first     2003-01-05 00:00:00
# last      2007-11-06 00:00:00
# Name: Date, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(x='Date',data=data )
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Count'>

# %%
data['Revenue'].describe()
# Out:
# count    10000.000000
# mean       295.573000
# std        105.850329
# min        190.000000
# 25%        220.000000
# 50%        280.000000
# 75%        310.000000
# max       1180.000000
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(x='Revenue',data=data )
# Out:
# <AxesSubplot:xlabel='Revenue'>

# %%
data['SAT_Score'].describe()
# Out:
# count    10000.000000
# mean         5.306600
# std          2.111739
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          7.000000
# max          9.000000
# Name: SAT_Score, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(x='SAT_Score',data=data )
# Out:
# <AxesSubplot:xlabel='SAT_Score'>
