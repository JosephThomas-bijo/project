# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(r"C:\Users\sidharth\Desktop\happycars\CustomerActivity.csv")
data.head()
# Out:
#    ActivityID  CustomerID              Date          EventType
# 0           0       11004  20-01-2003 00:00           Car Sale
# 1           1       11004  05-07-2003 00:00  Service - Neutral
# 2           2       11004  23-09-2003 00:00    Service - Happy
# 3           3       11006  31-01-2004 00:00           Car Sale
# 4           4       11006  15-07-2004 00:00  Service - Neutral

# %%
data.describe().transpose()
# Out:
#               count          mean           std      min      25%      50%  \
# ActivityID  49517.0  24758.000000  14294.470977      0.0  12379.0  24758.0
# CustomerID  49517.0  20363.382778   5281.610696  11004.0  15885.0  20412.0
#
#                 75%      max
# ActivityID  37137.0  49516.0
# CustomerID  24880.0  29474.0

# %%
data.isnull().sum()
# Out:
# ActivityID    0
# CustomerID    0
# Date          0
# EventType     0
# dtype: int64

# %%
data.Date.describe()
# Out:
# count                49517
# unique                1952
# top       06-10-2003 00:00
# freq                    67
# Name: Date, dtype: object

# %%
data['Date']=pd.to_datetime(data['Date'])
data.head()
# Out:
#    ActivityID  CustomerID       Date          EventType
# 0           0       11004 2003-01-20           Car Sale
# 1           1       11004 2003-05-07  Service - Neutral
# 2           2       11004 2003-09-23    Service - Happy
# 3           3       11006 2004-01-31           Car Sale
# 4           4       11006 2004-07-15  Service - Neutral

# %%
data.Date.describe()
# Out:
# <ipython-input-32-4fa25061bb96>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.Date.describe()
# count                   49517
# unique                   1952
# top       2003-06-10 00:00:00
# freq                       67
# first     2002-01-08 00:00:00
# last      2008-01-01 00:00:00
# Name: Date, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Date',kde=True)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Count'>

# %%
data.EventType.describe()
# Out:
# count                 49517
# unique                    5
# top       Service - Neutral
# freq                  15122
# Name: EventType, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='EventType')
# Out:
# <AxesSubplot:xlabel='EventType', ylabel='Count'>
