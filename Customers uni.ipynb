# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(r"C:\Users\sidharth\Desktop\happycars\Customers.csv")

# %%
data.head()
# Out:
#    CustomerID  FirstName LastName         BirthDate MaritalStatus  \
# 0       11004  Elizabeth  Johnson  08-08-1968 00:00             S
# 1       11006      Janet  Alvarez  06-12-1965 00:00             S
# 2       11007      Marco    Mehta  09-05-1964 00:00             M
# 3       11008        Rob  Verhoff  07-07-1964 00:00             S
# 4       11009    Shannon  Carlson  01-04-1964 00:00             S
#
#    YearlyIncome Gender  TotalChildren  NumberChildrenAtHome   Education  \
# 0  75001-100000      F              5                     5  Bachelors
# 1   50001-75000      F              0                     0  Bachelors
# 2   50001-75000      M              3                     3  Bachelors
# 3   50001-75000      F              4                     4  Bachelors
# 4   50001-75000      M              0                     0  Bachelors
#
#      Occupation  HomeOwner CommuteDistance  NumberOfPurchases  ProfitGenerated
# ...

# %%
data.describe().transpose()
# Out:
#                         count          mean          std         min  \
# CustomerID            10000.0  20325.469300  5275.706913  11004.0000
# TotalChildren         10000.0      2.072700     1.716132      0.0000
# NumberChildrenAtHome  10000.0      1.081300     1.534055      0.0000
# NumberOfPurchases     10000.0      2.251300     0.998222      1.0000
# ProfitGenerated       10000.0  12510.868637  9010.860651    796.1449
#
#                                25%         50%           75%         max
# CustomerID            15824.750000  20367.0000  24853.250000  29474.0000
# TotalChildren             0.000000      2.0000      4.000000      5.0000
# NumberChildrenAtHome      0.000000      0.0000      2.000000      6.0000
# NumberOfPurchases         2.000000      2.0000      3.000000      7.0000
# ProfitGenerated        5789.984275  10622.3929  17224.608875  61196.7654

# %%
data.isnull().sum()
# Out:
# CustomerID              0
# FirstName               0
# LastName                0
# BirthDate               0
# MaritalStatus           0
# YearlyIncome            0
# Gender                  0
# TotalChildren           0
# NumberChildrenAtHome    0
# Education               0
# Occupation              0
# HomeOwner               0
# CommuteDistance         0
# NumberOfPurchases       0
# ProfitGenerated         0
# dtype: int64

# %%
data.drop(['CustomerID','FirstName','LastName'],'columns',inplace=True)

# %%
data.head()
# Out:
#           BirthDate MaritalStatus  YearlyIncome Gender  TotalChildren  \
# 0  08-08-1968 00:00             S  75001-100000      F              5
# 1  06-12-1965 00:00             S   50001-75000      F              0
# 2  09-05-1964 00:00             M   50001-75000      M              3
# 3  07-07-1964 00:00             S   50001-75000      F              4
# 4  01-04-1964 00:00             S   50001-75000      M              0
#
#    NumberChildrenAtHome   Education    Occupation  HomeOwner CommuteDistance  \
# 0                     5  Bachelors   Professional       True       1-2 Miles
# 1                     0  Bachelors   Professional       True      5-10 Miles
# 2                     3  Bachelors   Professional       True       0-1 Miles
# 3                     4  Bachelors   Professional       True       10+ Miles
# 4                     0  Bachelors   Professional      False      5-10 Miles
#
#    NumberOfPurchases  ProfitGenerated
# 0                  5       10351.6657
# ...

# %%
data['BirthDate']=pd.to_datetime(data['BirthDate'])
data
# Out:
#       BirthDate MaritalStatus  YearlyIncome Gender  TotalChildren  \
# 0    1968-08-08             S  75001-100000      F              5
# 1    1965-06-12             S   50001-75000      F              0
# 2    1964-09-05             M   50001-75000      M              3
# 3    1964-07-07             S   50001-75000      F              4
# 4    1964-01-04             S   50001-75000      M              0
# ...         ...           ...           ...    ...            ...
# 9995 1977-04-05             S       0-25000      M              0
# 9996 1977-03-15             M       0-25000      M              0
# 9997 1960-08-25             S       0-25000      M              1
# 9998 1960-03-14             M       0-25000      F              1
# 9999 1959-04-10             M       0-25000      M              2
#
#       NumberChildrenAtHome        Education    Occupation  HomeOwner  \
# 0                        5       Bachelors   Professional       True
# ...

# %%
data['BirthDate'].describe()
# Out:
# <ipython-input-26-04d4a8b8a122>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data['BirthDate'].describe()
# count                   10000
# unique                   6105
# top       1964-07-14 00:00:00
# freq                        8
# first     1910-08-13 00:00:00
# last      1980-12-26 00:00:00
# Name: BirthDate, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(x='BirthDate',data=data )
# Out:
# <AxesSubplot:xlabel='BirthDate', ylabel='Count'>

# %%
data['MaritalStatus'].describe()
# Out:
# count     10000
# unique        2
# top           M
# freq       5363
# Name: MaritalStatus, dtype: object

# %%
print(data['MaritalStatus'].value_counts())
# Out:
# M    5363
# S    4637
# Name: MaritalStatus, dtype: int64

# %%
sns.histplot(data=data,x='MaritalStatus')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Count'>

# %%
data['TotalChildren'].describe()
# Out:
# count    10000.000000
# mean         2.072700
# std          1.716132
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          4.000000
# max          5.000000
# Name: TotalChildren, dtype: float64

# %%
data['Gender'].describe()
# Out:
# count     10000
# unique        2
# top           M
# freq       5087
# Name: Gender, dtype: object

# %%
sns.histplot(data=data,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
data['Education'].describe()
# Out:
# count               10000
# unique                  5
# top       Partial College
# freq                 2947
# Name: Education, dtype: object

# %%
print(data['Education'].value_counts())
# Out:
# Partial College        2947
# Bachelors              2770
# High School            2230
# Partial High School    1220
# Graduate Degree         833
# Name: Education, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Education')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
data['Occupation'].describe()
# Out:
# count            10000
# unique               5
# top       Professional
# freq              3345
# Name: Occupation, dtype: object

# %%
print(data['Occupation'].value_counts())
# Out:
# Professional      3345
# Skilled Manual    2277
# Management        2259
# Clerical          1079
# Manual            1040
# Name: Occupation, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Occupation')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Count'>

# %%
data['HomeOwner'].describe()
# Out:
# count     10000
# unique        2
# top        True
# freq       6464
# Name: HomeOwner, dtype: object

# %%
sns.histplot(data=data,x='HomeOwner')
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot:xlabel='HomeOwner', ylabel='Count'>

# %%
data['CommuteDistance'].describe()
# Out:
# count         10000
# unique            5
# top       0-1 Miles
# freq           2398
# Name: CommuteDistance, dtype: object

# %%
print(data['CommuteDistance'].value_counts())
# Out:
# 0-1 Miles     2398
# 5-10 Miles    2270
# 10+ Miles     2022
# 1-2 Miles     1753
# 2-5 Miles     1557
# Name: CommuteDistance, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='CommuteDistance')
# Out:
# <AxesSubplot:xlabel='CommuteDistance', ylabel='Count'>

# %%
data['YearlyIncome'].describe()
# Out:
# count           10000
# unique              5
# top       50001-75000
# freq             2871
# Name: YearlyIncome, dtype: object

# %%
print(data['YearlyIncome'].value_counts())
# Out:
# 50001-75000            2871
# 25001-50000            2611
# 75001-100000           1779
# greater than 100000    1432
# 0-25000                1307
# Name: YearlyIncome, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='YearlyIncome')
# Out:
# <AxesSubplot:xlabel='YearlyIncome', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(x='TotalChildren',data=data)
# Out:
# <AxesSubplot:xlabel='TotalChildren'>

# %%
data['NumberChildrenAtHome'].describe()
# Out:
# count    10000.000000
# mean         1.081300
# std          1.534055
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max          6.000000
# Name: NumberChildrenAtHome, dtype: float64

# %%
sns.boxplot(data=data,x='NumberChildrenAtHome')
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome'>

# %%
data['NumberOfPurchases'].describe()
# Out:
# count    10000.000000
# mean         2.251300
# std          0.998222
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max          7.000000
# Name: NumberOfPurchases, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(data=data,x='NumberOfPurchases')
# Out:
# <AxesSubplot:xlabel='NumberOfPurchases'>

# %%
data['ProfitGenerated'].describe()
# Out:
# count    10000.000000
# mean     12510.868637
# std       9010.860651
# min        796.144900
# 25%       5789.984275
# 50%      10622.392900
# 75%      17224.608875
# max      61196.765400
# Name: ProfitGenerated, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(data=data,x='ProfitGenerated')
# Out:
# <AxesSubplot:xlabel='ProfitGenerated'>

# %% [markdown]
# plt.figure(figsize=(10,4),dpi=200)
# sns.boxplot(y='ProfitGenerated',x='NumberOfPurchases',data=data)

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(y='ProfitGenerated',x='Gender',data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='ProfitGenerated'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(y='ProfitGenerated',x='MaritalStatus',data=data)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='ProfitGenerated'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(y='ProfitGenerated',x='CommuteDistance',data=data)
# Out:
# <AxesSubplot:xlabel='CommuteDistance', ylabel='ProfitGenerated'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(y='ProfitGenerated',x='Education',data=data)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='ProfitGenerated'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(y='ProfitGenerated',x='HomeOwner',data=data)
# Out:
# <AxesSubplot:xlabel='HomeOwner', ylabel='ProfitGenerated'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(y='ProfitGenerated',x='Occupation',data=data)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='ProfitGenerated'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(x='YearlyIncome',y='ProfitGenerated',data=data)
# Out:
# <AxesSubplot:xlabel='YearlyIncome', ylabel='ProfitGenerated'>
