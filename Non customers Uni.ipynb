# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(r"C:\Users\sidharth\Desktop\happycars\NonCustomers.csv")
data.head()
# Out:
#    NonCustomerID FirstName LastName         BirthDate MaritalStatus  \
# 0              0     Haley     Hall  14-08-1951 00:00             S
# 1              1     Bruce  Vazquez  11-02-1950 00:00             M
# 2              2     Amber     Hall  21-09-1957 00:00             M
# 3              3     Bruce    Ramos  11-06-1941 00:00             S
# 4              4    Bailey     Hall  14-05-1967 00:00             S
#
#   YearlyIncome Gender  TotalChildren  NumberChildrenAtHome  \
# 0      0-25000      F              2                     1
# 1  25001-50000      M              3                     0
# 2  25001-50000      F              2                     0
# 3      0-25000      M              2                     0
# 4  25001-50000      F              0                     0
#
#              Education      Occupation  HomeOwner CommuteDistance
# 0  Partial High School        Clerical       True      5-10 Miles
# 1      Partial College        Clerical      False      5-10 Miles
# ...

# %%
data.describe().transpose()
# Out:
#                        count         mean          std  min     25%     50%  \
# NonCustomerID         4245.0  2122.000000  1225.570275  0.0  1061.0  2122.0
# TotalChildren         4245.0     1.621908     1.500562  0.0     0.0     1.0
# NumberChildrenAtHome  4245.0     0.745819     1.264943  0.0     0.0     0.0
#
#                          75%     max
# NonCustomerID         3183.0  4244.0
# TotalChildren            3.0     5.0
# NumberChildrenAtHome     1.0     5.0

# %%
data.isnull().sum()
# Out:
# NonCustomerID           0
# FirstName               0
# LastName                0
# BirthDate               0
# MaritalStatus           0
# YearlyIncome            0
# Gender                  0
# TotalChildren           0
# NumberChildrenAtHome    0
# Education               0
# Occupation              0
# HomeOwner               0
# CommuteDistance         0
# dtype: int64

# %%
data.drop(['NonCustomerID','FirstName','LastName'],'columns',inplace=True)
data.head()
# Out:
#           BirthDate MaritalStatus YearlyIncome Gender  TotalChildren  \
# 0  14-08-1951 00:00             S      0-25000      F              2
# 1  11-02-1950 00:00             M  25001-50000      M              3
# 2  21-09-1957 00:00             M  25001-50000      F              2
# 3  11-06-1941 00:00             S      0-25000      M              2
# 4  14-05-1967 00:00             S  25001-50000      F              0
#
#    NumberChildrenAtHome            Education      Occupation  HomeOwner  \
# 0                     1  Partial High School        Clerical       True
# 1                     0      Partial College        Clerical      False
# 2                     0          High School  Skilled Manual      False
# 3                     0      Partial College          Manual      False
# 4                     0      Partial College  Skilled Manual      False
#
#   CommuteDistance
# 0      5-10 Miles
# 1      5-10 Miles
# 2       0-1 Miles
# 3       2-5 Miles
# 4       0-1 Miles

# %%
data['BirthDate']=pd.to_datetime(data['BirthDate'])
data
# Out:
#       BirthDate MaritalStatus YearlyIncome Gender  TotalChildren  \
# 0    1951-08-14             S      0-25000      F              2
# 1    1950-11-02             M  25001-50000      M              3
# 2    1957-09-21             M  25001-50000      F              2
# 3    1941-11-06             S      0-25000      M              2
# 4    1967-05-14             S  25001-50000      F              0
# ...         ...           ...          ...    ...            ...
# 4240 1958-09-25             M  25001-50000      F              1
# 4241 1958-03-29             M  50001-75000      F              1
# 4242 1959-05-14             M  50001-75000      F              1
# 4243 1973-03-24             S  25001-50000      F              0
# 4244 1955-03-25             M  25001-50000      F              1
#
#       NumberChildrenAtHome            Education      Occupation  HomeOwner  \
# 0                        1  Partial High School        Clerical       True
# ...

# %%
data['BirthDate'].describe()
# Out:
# <ipython-input-14-04d4a8b8a122>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data['BirthDate'].describe()
# count                    4245
# unique                   3401
# top       1977-09-20 00:00:00
# freq                        5
# first     1912-08-14 00:00:00
# last      1980-12-24 00:00:00
# Name: BirthDate, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.displot(data=data,x='BirthDate',kde=True)

# %%
data['MaritalStatus'].describe()
# Out:
# count     4245
# unique       2
# top          S
# freq      2188
# Name: MaritalStatus, dtype: object

# %%
sns.histplot(data=data,x='MaritalStatus')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='TotalChildren',data=data)
# Out:
# <AxesSubplot:xlabel='TotalChildren', ylabel='count'>

# %%
data['Gender'].describe()
# Out:
# count     4245
# unique       2
# top          M
# freq      2139
# Name: Gender, dtype: object

# %%
sns.histplot(data=data,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
data['Education'].describe()
# Out:
# count                4245
# unique                  5
# top       Partial College
# freq                 1628
# Name: Education, dtype: object

# %%
print(data['Education'].value_counts())
# Out:
# Partial College        1628
# Bachelors              1127
# High School             831
# Partial High School     346
# Graduate Degree         313
# Name: Education, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Education')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
data['Occupation'].describe()
# Out:
# count             4245
# unique               5
# top       Professional
# freq              1144
# Name: Occupation, dtype: object

# %%
print(data['Occupation'].value_counts())
# Out:
# Professional      1144
# Skilled Manual    1118
# Manual             740
# Clerical           663
# Management         580
# Name: Occupation, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Occupation')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Count'>

# %%
data['HomeOwner'].describe()
# Out:
# count     4245
# unique       2
# top       True
# freq      2669
# Name: HomeOwner, dtype: object

# %%
sns.histplot(data=data,x='HomeOwner')
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot:xlabel='HomeOwner', ylabel='Count'>

# %%
data['CommuteDistance'].describe()
# Out:
# count          4245
# unique            5
# top       0-1 Miles
# freq           1204
# Name: CommuteDistance, dtype: object

# %%
print(data['CommuteDistance'].value_counts())
# Out:
# 0-1 Miles     1204
# 2-5 Miles      979
# 5-10 Miles     845
# 1-2 Miles      795
# 10+ Miles      422
# Name: CommuteDistance, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='CommuteDistance')
# Out:
# <AxesSubplot:xlabel='CommuteDistance', ylabel='Count'>

# %%
data['YearlyIncome'].describe()
# Out:
# count            4245
# unique              5
# top       25001-50000
# freq             1459
# Name: YearlyIncome, dtype: object

# %%
print(data['YearlyIncome'].value_counts())
# Out:
# 25001-50000            1459
# 50001-75000            1407
# 0-25000                 737
# 75001-100000            498
# greater than 100000     144
# Name: YearlyIncome, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='YearlyIncome')
# Out:
# <AxesSubplot:xlabel='YearlyIncome', ylabel='Count'>

# %%
data['NumberChildrenAtHome'].describe()
# Out:
# count    4245.000000
# mean        0.745819
# std         1.264943
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         5.000000
# Name: NumberChildrenAtHome, dtype: float64

# %%
sns.boxplot(data=data,x='NumberChildrenAtHome')
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome'>

# %%
data['TotalChildren'].describe()
# Out:
# count    4245.000000
# mean        1.621908
# std         1.500562
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max         5.000000
# Name: TotalChildren, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(x='TotalChildren',data=data)
# Out:
# <AxesSubplot:xlabel='TotalChildren'>
